# %% [markdown]
# # Домашня робота №4

# %% [markdown]
# # Дискретні розподіли

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 Від'ємний біноміальний розподіл

# %% [markdown]
# Більш детальна інформація в [документації](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.nbinom.html).

# %%
from scipy.stats import nbinom, binom, geom

# %%
n = 5
p = 0.4

# %% [markdown]
# ### 1.1 Щільність

# %%
x = np.arange(-0.5, n*5+1, 0.5)

# %% [markdown]
# Виведіть значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
pmf = nbinom.pmf(x, n, p)
print(pmf)
# Out:
# [0.         0.01024    0.         0.03072    0.         0.055296
#  0.         0.0774144  0.         0.09289728 0.         0.10032906
#  0.         0.10032906 0.         0.09459597 0.         0.08513638
#  0.         0.07378486 0.         0.06197928 0.         0.05071032
#  0.         0.04056826 0.         0.03183048 0.         0.02455494
#  0.         0.01866175 0.         0.01399632 0.         0.01037374
#  0.         0.00760741 0.         0.00552538 0.         0.00397827
#  0.         0.00284162 0.         0.00201497 0.         0.00141924
#  0.         0.00099347 0.         0.00069145 0.        ]

# %% [markdown]
# Зобразіть графічно значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
plt.stem(pmf, use_line_collection=True)
plt.show()

# %% [markdown]
# Зобразіть графічно значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x1$.

# %%
x1 = np.arange(0, n*5+1)

# %%
plt.stem(nbinom.pmf(x1, n, p), use_line_collection=True)
plt.show()

# %% [markdown]
# ### 1.2 Функція розподілу

# %% [markdown]
# Виведіть значення функції розподілу від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
cdf = nbinom.cdf(x, n, p)
print(cdf)
# Out:
# [0.         0.01024    0.01024    0.04096    0.04096    0.096256
#  0.096256   0.1736704  0.1736704  0.26656768 0.26656768 0.36689674
#  0.36689674 0.4672258  0.4672258  0.56182178 0.56182178 0.64695815
#  0.64695815 0.72074301 0.72074301 0.78272229 0.78272229 0.83343262
#  0.83343262 0.87400087 0.87400087 0.90583135 0.90583135 0.93038629
#  0.93038629 0.94904805 0.94904805 0.96304436 0.96304436 0.9734181
#  0.9734181  0.98102551 0.98102551 0.98655089 0.98655089 0.99052917
#  0.99052917 0.99337079 0.99337079 0.99538576 0.99538576 0.996805
#  0.996805   0.99779847 0.99779847 0.99848993 0.99848993]

# %% [markdown]
# Зобразіть графічно значення функції розподілу від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
plt.stem(cdf, use_line_collection=True)
plt.show()

# %% [markdown]
# ### 1.3 Випадкові величини

# %% [markdown]
# Згенеруйте $100$ випадкових величин з від'ємного біноміального розподілу з параметрами $n, p$.

# %%
rvs = nbinom.rvs(n, p, size=100)
print(rvs)
# Out:
# [ 6  7  5  3 11  8  5  5  3 10 13 10 14  8 11  9  3  6  8  7  3  1  8 13
#   6 10 11 15 14  3  7 13  6  5  8  3 15 10  6 22 11  2  5 11  0  7  3  4
#  10  4  2  8 10  5  5  6  9  3 12  8  8  4  3  5  1  4 16  6 15  3  4  4
#   6  5 16  6 10 10 13  7  2 12  4 11  3  1  2  1 13  5  4  3  6 10  2  5
#   1  5  6  8]

# %% [markdown]
# Виведіть кількість кожного елемента в отриманому випадковому векторі.

# %%
from collections import Counter

c_rvs = Counter(rvs)
for i in c_rvs:
    print(f'el: {i}, count: {c_rvs[i]}')
# Out:
# el: 6, count: 11
# el: 7, count: 5
# el: 5, count: 12
# el: 3, count: 12
# el: 11, count: 6
# el: 8, count: 9
# el: 10, count: 9
# el: 13, count: 5
# el: 14, count: 2
# el: 9, count: 2
# el: 1, count: 5
# el: 15, count: 3
# el: 22, count: 1
# el: 2, count: 5
# el: 0, count: 1
# el: 4, count: 8
# el: 12, count: 2
# el: 16, count: 2

# %% [markdown]
# Зобразіть графічно кількість кожного елемента в отриманому випадковому векторі.

# %%
plt.hist(rvs)
plt.show()

# %% [markdown]
# ## 2 Гіпергеометричний розподіл

# %% [markdown]
# Більш детальна інформація в [документації](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.hypergeom.html).

# %%
from scipy.stats import hypergeom, poisson

# %%
M = 20
n = 7
N = 12

# %% [markdown]
# ### 2.1 Щільність

# %%
x = np.arange(max(0, N-M+n)-0.5, min(n, N)+1, 0.5)

# %% [markdown]
# Виведіть значення функції щільності гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x$.

# %%
pmf = hypergeom.pmf(x, M, n, N)
print(pmf)
# Out:
# [0.00000000e+00 1.03199174e-04 0.00000000e+00 4.33436533e-03
#  0.00000000e+00 4.76780186e-02 0.00000000e+00 1.98658411e-01
#  0.00000000e+00 3.57585139e-01 0.00000000e+00 2.86068111e-01
#  0.00000000e+00 9.53560372e-02 0.00000000e+00 1.02167183e-02
#  0.00000000e+00]

# %% [markdown]
# Зобразіть графічно значення функції щільності гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x$.

# %%
plt.stem(pmf, use_line_collection=True)
plt.show()

# %% [markdown]
# Зобразіть графічно значення функції щільності гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x1$.

# %%
x1 = np.arange(max(0, N-M+n), min(n, N)+1)

# %%
plt.stem(hypergeom.pmf(x1, M, n, N), use_line_collection=True)
plt.show()

# %% [markdown]
# ### 2.2 Функція розподілу

# %% [markdown]
# Виведіть значення функції розподілу гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x$.

# %%
cdf = hypergeom.cdf(x, M, n, N)
print(cdf)
# Out:
# [0.00000000e+00 1.03199174e-04 1.03199174e-04 4.43756450e-03
#  4.43756450e-03 5.21155831e-02 5.21155831e-02 2.50773994e-01
#  2.50773994e-01 6.08359133e-01 6.08359133e-01 8.94427245e-01
#  8.94427245e-01 9.89783282e-01 9.89783282e-01 1.00000000e+00
#  1.00000000e+00]

# %% [markdown]
# Зобразіть графічно значення функції розподілу гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x$.

# %%
plt.plot(x, cdf, drawstyle='steps-mid')
plt.show()

# %% [markdown]
# ### 2.3 Випадкові величини

# %% [markdown]
# Згенеруйте $100$ випадкових величин з гіпергеометричного розподілу з параметрами $M, n, N$.

# %%
rvs = hypergeom.rvs(M, n, N, size=100)
print(rvs)
# Out:
# [3 5 3 4 2 6 3 4 3 4 3 4 3 2 2 5 3 3 5 3 2 4 5 4 5 4 2 6 7 2 5 6 4 6 4 3 3
#  3 3 5 5 6 5 6 4 4 5 3 5 2 3 6 5 3 3 4 3 6 3 3 5 3 5 3 3 3 1 3 4 6 3 4 4 5
#  6 4 2 5 4 4 5 4 5 5 6 4 4 4 6 4 6 5 3 4 4 4 4 6 2 4]

# %% [markdown]
# Виведіть кількість кожного елемента в отриманому випадковому векторі.

# %%
c_rvs = Counter(rvs)
for i in c_rvs:
    print(f'el: {i}, count: {c_rvs[i]}')
# Out:
# el: 3, count: 27
# el: 5, count: 20
# el: 4, count: 28
# el: 2, count: 9
# el: 6, count: 14
# el: 7, count: 1
# el: 1, count: 1

# %% [markdown]
# Зобразіть графічно кількість кожного елемента в отриманому випадковому векторі.

# %%
plt.hist(rvs)
plt.show()

# %% [markdown]
# ## 3 Різні параметри

# %% [markdown]
# ### 3.1 Біноміальний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин біноміального розподілу з параметрами:
# 1. $n = 15, p = 0.8$
# 2. $n = 15, p = 0.2$
# 3. $n = 20, p = 0.4$
# 4. $n = 20, p = 0.6$
# 5. $n = 7, p = 0.5$
# 6. $n = 25, p = 0.5$
# 7. $n = 100, p = 0.5$

# %%
n = (15, 15, 20, 20, 7, 25, 100)
p = (0.8, 0.2, 0.4, 0.6, 0.5, 0.5, 0.5)

x = np.arange(0, 35, 0.5)

for i in range(7):
    print(f'n = {n[i]}, p = {p[i]}')

    rvs = binom.rvs(n[i], p[i], size=size)
    plt.figure(figsize=(25, 5))
    
    plt.subplot(1, 3, 1, title='Функция плотности')
    plt.stem(binom.pmf(x, n[i], p[i]), use_line_collection=True)
    
    plt.subplot(1, 3, 2, title='Функция распределения')
    plt.stem(binom.cdf(x, n[i], p[i]), use_line_collection=True)
    
    plt.subplot(1, 3, 3, title='Гистограмма')
    plt.hist(rvs)
    
    plt.show()
# Out:
# n = 15, p = 0.8
# n = 15, p = 0.2
# n = 20, p = 0.4
# n = 20, p = 0.6
# n = 7, p = 0.5
# n = 25, p = 0.5
# n = 100, p = 0.5

# %% [markdown]
# ### 3.2 Геометричний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин геометричного розподілу з параметрами:
# 1. $p = 0.1$
# 2. $p = 0.2$
# 3. $p = 0.3$
# 4. $p = 0.4$
# 5. $p = 0.5$
# 6. $p = 0.6$
# 7. $p = 0.7$
# 8. $p = 0.8$
# 9. $p = 0.9$

# %%
p = [i/10 for i in range(1, 10)]

for i in p:
    print(f'p = {i}')

    rvs = geom.rvs(i, size=100)
    plt.figure(figsize=(25, 5))
    
    plt.subplot(1, 3, 1, title='Функция плотности')
    plt.stem(geom.pmf(x, i), use_line_collection=True)
    
    plt.subplot(1, 3, 2, title='Функция распределения')
    plt.stem(geom.cdf(x, i), use_line_collection=True)
    
    plt.subplot(1, 3, 3, title='Гистограмма')
    plt.hist(rvs)
    
    plt.show()
# Out:
# p = 0.1
# p = 0.2
# p = 0.3
# p = 0.4
# p = 0.5
# p = 0.6
# p = 0.7
# p = 0.8
# p = 0.9

# %% [markdown]
# ### 3.3 Розподіл Пуассона

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин розподілу Пуассона з параметрами:
# 1. $\mu = 0.1$
# 2. $\mu = 0.2$
# 3. $\mu = 0.3$
# 4. $\mu = 0.4$
# 5. $\mu = 0.5$
# 6. $\mu = 0.6$
# 7. $\mu = 0.7$
# 8. $\mu = 0.8$
# 9. $\mu = 0.9$

# %%
u = p

for i in u:
    print(f'μ = {i}')
    
    plt.figure(figsize=(25, 5))
    rvs = poisson.rvs(i, size=100)
    
    plt.subplot(1, 3, 1, title='Функция плотности')
    plt.stem(poisson.pmf(x, i), use_line_collection=True)
    
    plt.subplot(1, 3, 2, title='Функция распределения')
    plt.stem(poisson.cdf(x, i), use_line_collection=True)
    
    plt.subplot(1, 3, 3, title='Гистограмма')
    plt.hist(rvs)
    
    plt.show()
# Out:
# μ = 0.1
# μ = 0.2
# μ = 0.3
# μ = 0.4
# μ = 0.5
# μ = 0.6
# μ = 0.7
# μ = 0.8
# μ = 0.9

# %% [markdown]
# ### 3.4 Від'ємний біноміальний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин від'ємного біноміального розподілу з параметрами:
# 1. $n = 15, p = 0.8$
# 2. $n = 15, p = 0.2$
# 3. $n = 20, p = 0.4$
# 4. $n = 20, p = 0.6$
# 5. $n = 7, p = 0.5$
# 6. $n = 25, p = 0.5$
# 7. $n = 100, p = 0.5$

# %%
n = (15, 15, 20, 20, 7, 25, 100)
p = (0.8, 0.2, 0.4, 0.6, 0.5, 0.5, 0.5)

for i in range(7):
    print(f'n = {n[i]}, p = {p[i]}')
    
    plt.figure(figsize=(25, 5))
    rvs = nbinom.rvs(n[i], p[i], size=100)
    
    plt.subplot(1, 3, 1, title='Функция плотности')
    plt.stem(nbinom.pmf(x, n[i], p[i]), use_line_collection=True)
    
    plt.subplot(1, 3, 2, title='Функция распределения')
    plt.stem(nbinom.cdf(x, n[i], p[i]), use_line_collection=True)
    
    plt.subplot(1, 3, 3, title='Гистограмма')
    plt.hist(rvs)
    
    plt.show()
# Out:
# n = 15, p = 0.8
# n = 15, p = 0.2
# n = 20, p = 0.4
# n = 20, p = 0.6
# n = 7, p = 0.5
# n = 25, p = 0.5
# n = 100, p = 0.5

# %% [markdown]
# ### 3.5 Гіпергеометричний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин гіпергеометричного розподілу з параметрами:
# 1. $M = 10, n = 3, N = 7$
# 2. $M = 50, n = 10, N = 5$
# 3. $M = 50, n = 10, N = 10$
# 4. $M = 50, n = 10, N = 20$
# 5. $M = 50, n = 10, N = 30$
# 6. $M = 50, n = 10, N = 40$
# 7. $M = 50, n = 10, N = 50$
# 8. $M = 50, n = 5, N = 25$
# 9. $M = 50, n = 15, N = 25$
# 10. $M = 50, n = 25, N = 25$
# 11. $M = 50, n = 35, N = 25$
# 12. $M = 50, n = 45, N = 25$

# %%
M = (10, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50)
n = (3, 10, 10, 10, 10, 10, 10, 5, 15, 25, 35, 45)
N = (7, 5, 10, 20, 30, 40, 50, 25, 25, 25, 25, 25)


for i in range(12):
    print(f'M = {M[i]}, n = {n[i]}, N = {N[i]}')
    
    plt.figure(figsize=(25, 5))
    rvs = hypergeom.rvs(M[i], n[i], N[i], size=100)
    
    plt.subplot(1, 3, 1, title='Функция плотности')
    plt.stem(hypergeom.pmf(rvs, M[i], n[i], N[i]), use_line_collection=True)
    
    plt.subplot(1, 3, 2, title='Функция распределения')
    plt.stem(hypergeom.cdf(rvs, M[i], n[i], N[i]), use_line_collection=True)
    
    plt.subplot(1, 3, 3, title='Гистограмма')
    plt.hist(rvs)
    
    plt.show()
# Out:
# M = 10, n = 3, N = 7
# M = 50, n = 10, N = 5
# M = 50, n = 10, N = 10
# M = 50, n = 10, N = 20
# M = 50, n = 10, N = 30
# M = 50, n = 10, N = 40
# M = 50, n = 10, N = 50
# M = 50, n = 5, N = 25
# M = 50, n = 15, N = 25
# M = 50, n = 25, N = 25
# M = 50, n = 35, N = 25
# M = 50, n = 45, N = 25

# %% [markdown]
# ## 4 Апроксимація біноміального розподілу розподілом Пуассона

# %% [markdown]
# Покажіть схожість біноміального розподілу та розподілу Пуассона (їх функцій щільності) з відповідними параметрами.
# Наприклад:
# - $n = 100, p = 0.05$
# - $n = 100, p = 0.1$
# - $n = 100, p = 0.15$
# - $n = 100, p = 0.2$
# - $n = 100, p = 0.35$
# - $n = 100, p = 0.5$
# - $n = 100, p = 0.75$

# %%
n = 100
p = (0.05, 0.1, 0.15, 0.2, 0.35, 0.5, 0.75)

x = np.arange(0, 100, 0.5)

for i in range(7):
    print(f'n = {n}, p = {p[i]}')
    
    plt.figure(figsize=(20, 5))
    
    plt.subplot(1, 2, 1, title='Биномиальное распределение')
    plt.stem(binom.pmf(x, n=n, p=p[i]), use_line_collection=True)
    
    plt.subplot(1, 2, 2, title='Распределение Пуассона')
    plt.stem(poisson.pmf(x, mu=p[i]), use_line_collection=True)

    plt.show()
# Out:
# n = 100, p = 0.05
# n = 100, p = 0.1
# n = 100, p = 0.15
# n = 100, p = 0.2
# n = 100, p = 0.35
# n = 100, p = 0.5
# n = 100, p = 0.75
